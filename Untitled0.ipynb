# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielaGuestory/MachineLearning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install SpeechRecognition gTTS wikipedia

import speech_recognition as sr
import webbrowser
import wikipedia
from gtts import gTTS
import os
from IPython.display import Audio, display
# Out:
# ...
#   Using cached speechrecognition-3.14.3-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached gTTS-2.5.4-py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached wikipedia-1.4.0-py3-none-any.whl
# ...
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# ...
# Using cached speechrecognition-3.14.3-py3-none-any.whl (32.9 MB)
# Using cached gTTS-2.5.4-py3-none-any.whl (29 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ...

# %%
def falar(texto, filename="resposta.mp3"):
    tts = gTTS(text=texto, lang="pt")
    tts.save(filename)
    display(Audio(filename, autoplay=True))

# %%
from google.colab import files

def ouvir():
    print("📂 Faça upload de um arquivo de áudio (.wav)")
    uploaded = files.upload()

    for fn in uploaded.keys():
        recognizer = sr.Recognizer()
        with sr.AudioFile(fn) as source:
            audio = recognizer.record(source)
        try:
            texto = recognizer.recognize_google(audio, language="pt-BR")
            print(f"Você disse: {texto}")
            return texto.lower()
        except sr.UnknownValueError:
            print("Não entendi o áudio.")
            return ""
        except sr.RequestError:
            print("Erro na API do Google.")
            return ""

# %%
def executar_comando(comando):
    if "wikipedia" in comando:
        falar("O que você deseja pesquisar na Wikipédia?")
        termo = ouvir()
        if termo:
            try:
                resumo = wikipedia.summary(termo, sentences=2, auto_suggest=False)
                print(resumo)
                falar(resumo)
            except:
                falar("Não encontrei nada sobre isso.")

    elif "youtube" in comando:
        falar("Abrindo o YouTube...")
        webbrowser.open("https://www.youtube.com")

    elif "farmácia" in comando:
        falar("Abrindo a farmácia mais próxima no Google Maps...")
        webbrowser.open("https://www.google.com/maps/search/farmácia+perto+de+mim/")

    elif "sair" in comando:
        falar("Até logo!")
        return False

    else:
        falar("Não entendi o comando.")

    return True

# %%
falar("Olá, eu sou sua assistente virtual. Como posso ajudar?")

ativo = True
while ativo:
    comando = ouvir()
    if comando:
        ativo = executar_comando(comando)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 📂 Faça upload de um arquivo de áudio (.wav)
#      <input type="file" id="files-5e6844a9-f695-45c8-b09d-8870bd6017eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e6844a9-f695-45c8-b09d-8870bd6017eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# ...

# %%
import speech_recognition as sr

# Caminho do arquivo que você carregou
audio_path = "/mnt/data/abrir-navegador-na-página-do-youtube.wav"

recognizer = sr.Recognizer()
with sr.AudioFile(audio_path) as source:
    audio = recognizer.record(source)

try:
    texto = recognizer.recognize_google(audio, language="pt-BR")
    print("🗣️ Texto reconhecido:", texto)
except sr.UnknownValueError:
    print("Não consegui entender o áudio.")
except sr.RequestError:
    print("Erro ao acessar a API do Google.")
