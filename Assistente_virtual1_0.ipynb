# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielaGuestory/MachineLearning/blob/main/Assistente_virtual1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install SpeechRecognition gTTS wikipedia

import speech_recognition as sr
import wikipedia
from gtts import gTTS
import os
from IPython.display import Audio, display, HTML
from google.colab import files
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 51.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 8.8 MB/s eta 0:00:00
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=f572cd33de32b7d99125a524b00655a21459e5568aa91e9c30f3c9188be6d57c
#   Stored in directory: /root/.cache/pip/wheels/63/47/7c/a9688349aa74d228ce0a9023229c6c0ac52ca2a40fe87679b8
# Successfully built wikipedia
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ...

# %%
def falar(texto, filename="resposta.mp3"):
    """Converte texto em fala e reproduz no Colab"""
    tts = gTTS(text=texto, lang="pt")
    tts.save(filename)
    display(Audio(filename, autoplay=True))

# %%
def ouvir():
    """Faz upload de um arquivo .wav e converte fala em texto"""
    print("📂 Faça upload de um arquivo de áudio (.wav)")
    uploaded = files.upload()

    for fn in uploaded.keys():
        recognizer = sr.Recognizer()
        with sr.AudioFile(fn) as source:
            audio = recognizer.record(source)
        try:
            texto = recognizer.recognize_google(audio, language="pt-BR")
            print(f"🗣️ Você disse: {texto}")
            return texto.lower()
        except sr.UnknownValueError:
            print("❌ Não entendi o áudio.")
            return ""
        except sr.RequestError:
            print("⚠️ Erro na API do Google.")
            return ""

# %%
def executar_comando(comando):
    if "wikipedia" in comando:
        falar("O que você deseja pesquisar na Wikipédia?")
        termo = ouvir()
        if termo:
            try:
                resumo = wikipedia.summary(termo, sentences=2, auto_suggest=False)
                print("📖 Resumo da Wikipédia:", resumo)
                falar(resumo)
                display(HTML(f'<a href="https://pt.wikipedia.org/wiki/{termo}" target="_blank">🔗 Abrir Wikipedia sobre {termo}</a>'))
            except:
                falar("Não encontrei nada sobre isso.")

    elif "youtube" in comando:
        falar("Abrindo o YouTube, clique no link abaixo.")
        display(HTML('<a href="https://www.youtube.com" target="_blank">🔗 Clique aqui para abrir o YouTube</a>'))

    elif "farmácia" in comando:
        falar("Abrindo a farmácia mais próxima no Google Maps, clique no link abaixo.")
        display(HTML('<a href="https://www.google.com/maps/search/farmácia+perto+de+mim/" target="_blank">🔗 Clique aqui para abrir farmácias próximas</a>'))

    elif "sair" in comando:
        falar("Até logo!")
        return False

    else:
        falar("Não entendi o comando.")

    return True

# %%
falar("Olá, eu sou sua assistente virtual. Como posso ajudar?")

ativo = True
while ativo:
    comando = ouvir()
    if comando:
        ativo = executar_comando(comando)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 📂 Faça upload de um arquivo de áudio (.wav)
#      <input type="file" id="files-443212e4-d65b-4186-8f8d-367aac139c50" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-443212e4-d65b-4186-8f8d-367aac139c50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# ...
